# %% [markdown]
# - Exercici 1
# Crea una funció que donat un Array d’una dimensió, et faci un resum estadístic bàsic de les dades. Si detecta que l’array té més d’una dimensió, ha de mostrar un missatge d’error.
#
#
#
# - Exercici 2
# Crea una funció que et generi un quadrat NxN de nombres aleatoris entre el 0 i el 100.
#
#
#
# - Exercici 3
# Crea una funció que donada una taula de dues dimensions (NxM), et calculi els totals per fila i els totals per columna.
#
#
#
# - Exercici 4
# Implementa manualment una funció que calculi el coeficient de correlació. Informa-te'n sobre els seus usos i interpretació.

# %% [markdown]
# # E1
# Crea una funció que donat un Array d’una dimensió, et faci un resum estadístic bàsic de les dades. Si detecta que l’array té més d’una dimensió, ha de mostrar un missatge d’error.

# %%
# primer carreguem numpy
import numpy as np
import pandas as pd

# %%
#creem dos arrays, un d'una dimensió i un de més d'una
i=np.random.randint(1,100)
j=np.random.randint(1,100)
a=np.random.randint(100, size=(i))
b=np.random.randint(100, size=(i,j))

# %%
# descripció estatística utilitzant scipy
from scipy import stats
stats.describe(a)
# Out:
# DescribeResult(nobs=47, minmax=(0, 97), mean=45.0, variance=841.2173913043479, skewness=0.19220315536922195, kurtosis=-1.1809309465417772)

# %%
# descripció estadística fent servir pandas
a_df = pd.DataFrame(a)
a_df.describe()
# Out:
#                0
# count  47.000000
# mean   45.000000
# std    29.003748
# min     0.000000
# 25%    19.500000
# 50%    42.000000
# 75%    66.500000
# max    97.000000

# %%
# definim la funció per aplicar l'anàlisi bàsic a un array
def E1():
    if(array.ndim<2):
        a_df = pd.DataFrame(array)
        print(a_df.describe())
    else:
        print("Error, aquest array té més d'una dimensió")

# %%
# declarem la variable array amb qualsevol dels arrays anteriors i cridem la funció
array = b
E1()
# Out:
# Error, aquest array té més d'una dimensió

# %% [markdown]
# # E2
# Crea una funció que et generi un quadrat NxN de nombres aleatoris entre el 0 i el 100

# %%
def E2():
    N=np.random.randint(1,100)
    array = np.random.randint(100, size=(N,N))
E2()
print(array)
# Out:
# [[58 16 23 ... 76 92 65]
#  [54 84 21 ... 25 15 29]
#  [20 75 37 ... 50 43 99]
#  ...
#  [86 70 78 ...  4 56 42]
#  [ 3 41 53 ... 20 70 50]
#  [41 10 20 ... 91  7 49]]

# %% [markdown]
# # E3
# Crea una funció que donada una taula de dues dimensions (NxM), et calculi els totals per fila i els totals per columna.

# %%
array.sum(axis=0)
# Out:
# array([2325, 2427, 2245, 2380, 2122, 2484, 2707, 2176, 2253, 2529, 2488,
#        2094, 2684, 2367, 2554, 2358, 2406, 2347, 2250, 2249, 2352, 2130,
#        2603, 2542, 2067, 2232, 2477, 2497, 2195, 2524, 2331, 2317, 2127,
#        2450])

# %%
def E3():
    arraysumV=array.sum(axis=0)
    arraysumH=array.sum(axis=1)
    print("la suma vertical del array es: ")
    print(arraysumV)
    print("la suma horizontal del array es: ")
    print(arraysumH)
    
E3()
# investigar perquè no puc imprimir una variable que es declara dintre d'una funció fora d'aquesta funció, segurament per contenidors, perquè només existeix dintre del contenidor E3 en aquest cas.
# Out:
# la suma vertical del array es:
# [2325 2427 2245 2380 2122 2484 2707 2176 2253 2529 2488 2094 2684 2367
#  2554 2358 2406 2347 2250 2249 2352 2130 2603 2542 2067 2232 2477 2497
#  2195 2524 2331 2317 2127 2450]
# la suma horizontal del array es:
# [1893 1465 2038 1859 1822 1838 1511 1383 1893 1784 1998 1951 1905 1557
#  1722 1485 1581 1648 1555 1917 1470 1495 2058 1453 1695 1642 1365 1579
#  1651 1686 1909 1571 1781 1758 1625 1619 1718 1798 1642 1941 1652 1963
#  1525 1896 1642 1842 1508]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 print(arraysumV)
#
# NameError: name 'arraysumV' is not defined

# %% [markdown]
# # E4
# Implementa manualment una funció que calculi el coeficient de correlació. Informa-te'n sobre els seus usos i interpretació.
# ![image.png](attachment:image.png)

# %%
#massa complicat intentant aplicar la formula literal, busca una altra forma
import math
def E4fail():
    N = np.random.randint(1,10)
    x = np.random.randint(10, size=(1,N))
    y = np.random.randint(10, size=(1,N))
    Sx = x.sum()
    Sqx = sum(map(lambda i : i * i, x))
    Ssqx = Sqx.sum()
    Sy = y.sum()
    Sqy = sum(map(lambda i : i * i, y))
    Ssqy = Sqy.sum()
    Sxy= x.sum() + y.sum()
    argx = Ssqx-(Sx*Sx)
    argy = Ssqy-(Sy*Sy)
    # no sé perquè la fòrmula superior no suma els quadrats
   
    print(argx)
    print(Ssqx)
    print(Sqx)
    print(Sx)
    print(x)

# %%
N = np.random.randint(1,10)
x = np.random.randint(10, size=(N,3))
dfx = pd.DataFrame(x, columns = ['A','B','C'])

# %%
def E4(df, x, y):
    x_b = df[x].mean()
    y_b = df[y].mean()
    # sample deviation
    x_sd = df[x].std()
    y_sd = df[y].std()
    r = ((df[x]-x_b)/x_sd)*((df[y]-y_b)/y_sd)
    corr = r/(df.shape[0]-1)
    
    return corr

# %%
E4(dfx,'B','A')
#?? no ho entenc
# Out:
# 0   -0.331133
# 1   -0.264906
# 2    0.198680
# dtype: float64
